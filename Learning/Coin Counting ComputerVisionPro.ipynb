# %%
#https://www.youtube.com/watch?v=rRcwuQGDFOA
import cv2
import numpy as np
import matplotlib.pyplot as plt

print("Your OpenCV version is: " + cv2.__version__)
# Out:
# Your OpenCV version is: 4.8.0

# %%
image = cv2.imread('Coins/6 coins.jfif')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image, cmap="gray")

# %%
#blur = cv2.GaussianBlur(gray, (11,11), 0)  #original
blur = cv2.GaussianBlur(gray, (15,15), 0)
#blur = cv2.GaussianBlur(gray, (21,21), 0)
plt.imshow(blur, cmap="gray")

# %%
canny = cv2.Canny(blur, 30, 150, 3)
plt.imshow(canny, cmap="gray")

# %%
dilated = cv2.dilate(canny, (1,1), iterations = 2)
plt.imshow(dilated,cmap="gray")

# %%
(cnt, heirachy) = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)   #converting imaje to rgb
cv2.drawContours(rgb, cnt, -1, (0,255,0), 2)

plt.imshow(rgb)

# %%
print("coins in image: ", len(cnt))
#Almost worked, counted 11 coins out of 6.
# Out:
# coins in image:  11
