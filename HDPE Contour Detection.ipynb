# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

print("Your OpenCV version is: " + cv2.__version__)
# Out:
# Your OpenCV version is: 4.8.0

# %%
#make it grey
image = cv2.imread('Pellets/HDPE/HDPE_126_(1).png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#plt.imshow(gray, cmap="gray")
plt.imshow(gray)

# %%
ret, thresh = cv2.threshold(gray,100,255,cv2.THRESH_BINARY)

plt.imshow(thresh)

# %%
#blur it
#blur = cv2.GaussianBlur(gray, (11,11), 0)  #original
blur = cv2.GaussianBlur(thresh, (15,15), 0)
#blur = cv2.GaussianBlur(gray, (21,21), 0)
plt.imshow(blur)

# %%
canny = cv2.Canny(blur, 30, 150, 3)
plt.imshow(canny)

# %%
dilated = cv2.dilate(canny, (1,1), iterations = 2)
plt.imshow(dilated,cmap="gray")

# %%
(cnt, heirachy) = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)   #converting bgr to rgb
cv2.drawContours(rgb, cnt, -1, (0,255,0), 2)

plt.imshow(rgb)

# %%
print("coins in image: ", len(cnt))
#Almost worked, counted 112 pellets out of 126.
# Out:
# coins in image:  105
